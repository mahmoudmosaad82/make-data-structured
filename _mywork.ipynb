# %%
import requests 
import csv

# %%
data=requests.get("https://dummyjson.com/carts")

# %%
data=data.json()

# %%
data.keys()
# Out:
# dict_keys(['carts', 'total', 'skip', 'limit'])

# %%
import pandas as pd
import csv

# assuming `df` is a pandas DataFrame
with open('output1.csv', 'w', newline='') as f:
    fieldnames = ['id', 'title', 'price', 'quantity', 'total', 'discountPercentage', 'discountedPrice']
    writer = csv.DictWriter(f, fieldnames=fieldnames)
    writer.writeheader()
    for row in df:
        writer.writerow(row)

# %%
with open("outpu2t.csv", mode='w', newline="") as csv_file:
    field_name=['id','title','price','quantity','total','discountPercentage','discountedPrice']
    writer=csv.DictWriter(csv_file,fieldnames=field_name)
    writer.writeheader()
    for i in df:
        writer.writerow(i)

# %%
with open('data.csv', mode='w', newline='') as csv_file:
    writer = csv.writer(csv_file)
    writer.writerow(['ID','Title','Price','Quantity','Total','Discount Percentage','Discount Price'])
    for i in df:
        writer.writerow([i['id'],i['title'],i['price'],i['quantity'],i['total'],i['discountPercentage'],i['discountedPrice']])

# %%
data['carts']
# Out:
# [{'id': 1,
#   'products': [{'id': 59,
#     'title': 'Spring and summershoes',
#     'price': 20,
#     'quantity': 3,
#     'total': 60,
#     'discountPercentage': 8.71,
#     'discountedPrice': 55},
#    {'id': 88,
#     'title': 'TC Reusable Silicone Magic Washing Gloves',
#     'price': 29,
#     'quantity': 2,
#     'total': 58,
#     'discountPercentage': 3.19,
#     'discountedPrice': 56},
#    {'id': 18,
#     'title': 'Oil Free Moisturizer 100ml',
#     'price': 40,
#     'quantity': 2,
#     'total': 80,
#     'discountPercentage': 13.1,
#     'discountedPrice': 70},
#    {'id': 95,
#     'title': 'Wholesale cargo lashing Belt',
#     'price': 930,
#     'quantity': 1,
#     'total': 930,
#     'discountPercentage': 17.67,
#     'discountedPrice': 766},
#    {'id': 39,
#     'title': 'Women Sweaters Wool',
#     'price': 600,
#     'quantity': 2,
#     'total': 1200,
#     'discountPercentage': 17.2,
#     'discountedPrice': 994}],
#   'total': 2328,
# ...

# %%
data['carts']
# Out:
# [{'id': 1,
#   'products': [{'id': 59,
#     'title': 'Spring and summershoes',
#     'price': 20,
#     'quantity': 3,
#     'total': 60,
#     'discountPercentage': 8.71,
#     'discountedPrice': 55},
#    {'id': 88,
#     'title': 'TC Reusable Silicone Magic Washing Gloves',
#     'price': 29,
#     'quantity': 2,
#     'total': 58,
#     'discountPercentage': 3.19,
#     'discountedPrice': 56},
#    {'id': 18,
#     'title': 'Oil Free Moisturizer 100ml',
#     'price': 40,
#     'quantity': 2,
#     'total': 80,
#     'discountPercentage': 13.1,
#     'discountedPrice': 70},
#    {'id': 95,
#     'title': 'Wholesale cargo lashing Belt',
#     'price': 930,
#     'quantity': 1,
#     'total': 930,
#     'discountPercentage': 17.67,
#     'discountedPrice': 766},
#    {'id': 39,
#     'title': 'Women Sweaters Wool',
#     'price': 600,
#     'quantity': 2,
#     'total': 1200,
#     'discountPercentage': 17.2,
#     'discountedPrice': 994}],
#   'total': 2328,
# ...

# %%
df= data['carts'][0]['products']
df
# Out:
# [{'id': 59,
#   'title': 'Spring and summershoes',
#   'price': 20,
#   'quantity': 3,
#   'total': 60,
#   'discountPercentage': 8.71,
#   'discountedPrice': 55},
#  {'id': 88,
#   'title': 'TC Reusable Silicone Magic Washing Gloves',
#   'price': 29,
#   'quantity': 2,
#   'total': 58,
#   'discountPercentage': 3.19,
#   'discountedPrice': 56},
#  {'id': 18,
#   'title': 'Oil Free Moisturizer 100ml',
#   'price': 40,
#   'quantity': 2,
#   'total': 80,
#   'discountPercentage': 13.1,
#   'discountedPrice': 70},
#  {'id': 95,
#   'title': 'Wholesale cargo lashing Belt',
#   'price': 930,
#   'quantity': 1,
#   'total': 930,
#   'discountPercentage': 17.67,
#   'discountedPrice': 766},
#  {'id': 39,
#   'title': 'Women Sweaters Wool',
#   'price': 600,
#   'quantity': 2,
#   'total': 1200,
#   'discountPercentage': 17.2,
#   'discountedPrice': 994}]
